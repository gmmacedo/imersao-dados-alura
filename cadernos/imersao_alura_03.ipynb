# %%
import pandas as pd  ## Importando a biblioteca pandas

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.columns = dados.columns.str.replace('-','')
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa={'droga': 'composto'}
dados.rename(columns= mapa, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %% [markdown]
# Dessa forma os dados estão na proporção da soma de todos os valores, isso não é o que queremos. O desejado é fazer a proporção entre o controle e a droga, para isso vamos adicionar um parâmetro para a proporção das linhas, ou seja, fazer a proporção do index.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# Nesse comando pegamos os dados da dose e do tempo em relação ao tratamento para os valores da coluna 'g0' e depois fazendo a média desses valores.

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='g0', y='g3', data=dados)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='g0', y='g8', data=dados)

# %% [markdown]
# Como pode perceber o gráfico passa algumas informações, porém elas não são tão nítidas e parece mais apenas uma núvem de pontos. Para tentar deixar o gráfico mais nítido vamos usar outro método:

# %%
#plt.figure(figsize=(10,8))
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color': 'red'})

# %% [markdown]
# Com isso vamos tentar comparar dados diferentes em relação a esses dois genes diferentes e colocar os gráficos lado a lado.

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
import numpy as np
corr = dados.loc[:,'g0' : 'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ###Desafio 01: Criar tabelas de frequência com o pandas.groupby()
#
# ###Desafio 02: Normalizar o crosstab pela coluna.
#
# ###Desafio 03: Explorar outros agregadores.
#
# ###Desafio 04: Explorar o melt.
#
# ###Desafio 05: Calcular e analizar a correlação entre G e C
#
# ###Desafio 06: Estudar o código do heatmap.
#
# ###Desafio 07: Resumo do que aprendeu com os dados.

# %% [markdown]
# ##Desafio 01:

# %%
dados.groupby(by=['tratamento', 'tempo'])['g0'].std()
# Out:
# tratamento    tempo
# com_controle  24       0.805560
#               48       0.847718
#               72       0.844649
# com_droga     24       1.276990
#               48       1.529975
#               72       1.455071
# Name: g0, dtype: float64

# %%
dados.groupby(by=['dose', 'tempo'])['g0'].mean()
# Out:
# dose  tempo
# D1    24       0.319991
#       48       0.370304
#       72       0.240556
# D2    24       0.107051
#       48       0.198721
#       72       0.239057
# Name: g0, dtype: float64

# %% [markdown]
# ##Desafio 02:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ##Desafio 03:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index', values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -2.165955   3.165955
#      48        -0.423801   1.423801
#      72        32.731343 -31.731343
# D2   24         0.085345   0.914655
#      48         0.057868   0.942132
#      72         0.217029   0.782971

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index', values=dados['g0'], aggfunc='std')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.339483   0.660517
#      48         0.335020   0.664980
#      72         0.345301   0.654699
# D2   24         0.444630   0.555370
#      48         0.388810   0.611190
#      72         0.376911   0.623089

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index', values=dados['g0'], aggfunc='count')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# ##Desafio 04:

# %%
pd.melt(dados, id_vars=['composto', 'id', 'tempo'], value_vars=['g5'], var_name='genes', value_name='teste')
# Out:
#         composto            id  tempo genes   teste
# 0      b68db1d53  id_000644bb2     24    g5 -1.0120
# 1      df89a8e5a  id_000779bfc     72    g5  0.5207
# 2      18bb41b2c  id_000a6266a     48    g5  1.2390
# 3      8c7f86626  id_0015fd391     48    g5 -0.8095
# 4      7cbed3131  id_001626bd3     72    g5 -0.8244
# ...          ...           ...    ...   ...     ...
# 23809  df1d0a5a1  id_fffb1ceed     24    g5  0.7201
# 23810  ecf3b6b74  id_fffb70c0c     24    g5  0.6621
# 23811  cacb2b860  id_fffc1c3f4     48    g5 -0.0159
# 23812  8b87a7a83  id_fffcb9e7c     24    g5 -0.0343
# 23813  972f41291  id_ffffdd77b     72    g5 -3.6750
#
# [23814 rows x 5 columns]

# %%
pd.melt(dados, id_vars=['composto', 'tratamento', 'tempo'], value_vars=['g5'], var_name='genes')
# Out:
#         composto    tratamento  tempo genes   value
# 0      b68db1d53     com_droga     24    g5 -1.0120
# 1      df89a8e5a     com_droga     72    g5  0.5207
# 2      18bb41b2c     com_droga     48    g5  1.2390
# 3      8c7f86626     com_droga     48    g5 -0.8095
# 4      7cbed3131     com_droga     72    g5 -0.8244
# ...          ...           ...    ...   ...     ...
# 23809  df1d0a5a1     com_droga     24    g5  0.7201
# 23810  ecf3b6b74     com_droga     24    g5  0.6621
# 23811  cacb2b860  com_controle     48    g5 -0.0159
# 23812  8b87a7a83     com_droga     24    g5 -0.0343
# 23813  972f41291     com_droga     72    g5 -3.6750
#
# [23814 rows x 5 columns]

# %% [markdown]
# ##Desadio 05:

# %%
t_droga = dados.query('tratamento == "com_droga"')

genes = t_droga.loc[:, 'g0' : 'g25']
c = t_droga.loc[:, 'c0' : 'c25']

merge = pd.concat([genes, c], axis=1)
merge

## Retirei todos os dados dos experimentos que foram controle e então recortei as colunas do g0 até g25 e do c0 ao c25
## Daí eu juntei os dois dataframes.
# Out:
#            g0      g1      g2      g3  ...     c22     c23     c24     c25
# 0      1.0620  0.5577 -0.2479 -0.6208  ... -0.3971 -0.2115 -0.2687  0.5196
# 1      0.0743  0.4087  0.2991  0.0604  ...  0.4864 -0.0140  0.0164  0.1759
# 2      0.6280  0.5817  1.5540 -0.0764  ... -0.1602 -0.2028 -0.2216 -1.1380
# 3     -0.5138 -0.2491 -0.2656  0.5288  ... -1.9180 -0.6761 -2.8360 -1.6890
# 4     -0.3254 -0.4009  0.9700  0.6919  ...  1.0600 -0.4255  0.8624  1.0010
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23808  0.1608 -1.0500  0.2551 -0.2239  ...  0.1063  0.7528  0.2746 -0.1976
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.1439  0.3021 -0.0546  0.7490
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  0.8420 -0.9363 -0.6085  0.9446
# 23812  0.6660  0.2324  0.4392  0.2044  ... -1.0770  0.7400  0.7976  0.2998
# 23813 -0.8598  1.0240 -0.1361  0.7952  ... -1.8990 -2.1730 -2.8110 -5.8430
#
# [21948 rows x 52 columns]

# %%
corr = merge.corr()
corr
# Out:
#            g0        g1        g2  ...       c23       c24       c25
# g0   1.000000  0.071546  0.176710  ... -0.589398 -0.667832 -0.613271
# g1   0.071546  1.000000 -0.050010  ...  0.024969 -0.005086  0.030136
# g2   0.176710 -0.050010  1.000000  ... -0.196196 -0.174218 -0.174531
# g3   0.023815 -0.011016  0.040901  ... -0.004557 -0.064364 -0.008839
# g4   0.410954  0.164478  0.025538  ... -0.364843 -0.404968 -0.383920
# g5  -0.170003 -0.144854  0.014120  ...  0.185451  0.209798  0.205619
# g6   0.257568 -0.115735  0.020787  ... -0.111425 -0.099015 -0.082861
# g7  -0.406262  0.128779 -0.153612  ...  0.513744  0.589513  0.531786
# g8  -0.614090 -0.002324 -0.130559  ...  0.567594  0.601994  0.567046
# g9  -0.437885 -0.041429 -0.085536  ...  0.462445  0.491947  0.464813
# g10 -0.566067 -0.001983 -0.114650  ...  0.598783  0.658333  0.610494
# g11  0.221179  0.161415  0.011606  ... -0.193269 -0.247387 -0.212715
# g12 -0.209361  0.044962 -0.063864  ...  0.391319  0.371834  0.380296
# ...

# %%
re_corr = corr.loc[:'g25', 'c0':]
re_corr
# Out:
#            c0        c1        c2  ...       c23       c24       c25
# g0  -0.631908 -0.633972 -0.647684  ... -0.589398 -0.667832 -0.613271
# g1  -0.031841 -0.023024 -0.031111  ...  0.024969 -0.005086  0.030136
# g2  -0.171517 -0.184193 -0.181112  ... -0.196196 -0.174218 -0.174531
# g3  -0.040447 -0.098196 -0.091010  ... -0.004557 -0.064364 -0.008839
# g4  -0.418163 -0.390767 -0.404131  ... -0.364843 -0.404968 -0.383920
# g5   0.215371  0.205295  0.217897  ...  0.185451  0.209798  0.205619
# g6  -0.118444 -0.095505 -0.095426  ... -0.111425 -0.099015 -0.082861
# g7   0.506307  0.576042  0.587199  ...  0.513744  0.589513  0.531786
# g8   0.626995  0.607203  0.602322  ...  0.567594  0.601994  0.567046
# g9   0.446771  0.487008  0.500464  ...  0.462445  0.491947  0.464813
# g10  0.601936  0.660332  0.658062  ...  0.598783  0.658333  0.610494
# g11 -0.232648 -0.270412 -0.276044  ... -0.193269 -0.247387 -0.212715
# g12  0.355190  0.370312  0.367588  ...  0.391319  0.371834  0.380296
# ...

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(re_corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
hm = sns.heatmap(re_corr, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
hm.set_xlabel='Células'
hm.set_ylabel='Genes'
hm.set_title='Genes x Células'
